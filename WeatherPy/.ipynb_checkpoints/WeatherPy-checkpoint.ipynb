# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 640

# %%
#cities = cities[]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).
#
# > **HINT:** The OpenWeatherMap API only allows 60 calls per minute under their free plan. Try using `time.sleep(60)` after each set of 50 cities to avoid API errors due to large calls.

# %%
#set varibles for each item collected from call to be appended to list
temperature = []
humidity = []
cloudiness = []
wind_speed = []
long = []
lati = []
city_name = []
country= []

#create loop to iterate through cities and pull data for set variables
for city in cities:
    #begin api call for weather
    #include try/except for any errors if any
    try:
        url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=imperial"
        response = requests.get(url)
        response_json = response.json()
        pprint(response_json)
        #get data to append to each variable
        temperature.append(response_json["main"]["temp_max"])
        humidity.append(response_json["main"]["humidity"])
        cloudiness.append(response_json["clouds"]["all"])
        wind_speed.append(response_json["wind"]["speed"])
        long.append(response_json["coord"]["lon"])
        lati.append(response_json["coord"]["lat"])
        city_name.append(response_json["name"])
        country.append(response_json["sys"]["country"])
        
                
        
        
        print(f"{city} is found")
    except:
        print("city not found")
        
    #sleep not to overload api call
    time.sleep(1)
    print()
# Out:
# {'cod': '404', 'message': 'city not found'}
# city not found
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 32.7941, 'lon': -79.8626},
#  'dt': 1650769752,
#  'id': 4588165,
#  'main': {'feels_like': 65.79,
#           'humidity': 95,
#           'pressure': 1024,
#           'temp': 65.1,
#           'temp_max': 68,
#           'temp_min': 62.08},
#  'name': 'Mt. Pleasant',
#  'sys': {'country': 'US',
#          'id': 2035120,
#          'sunrise': 1650710423,
#          'sunset': 1650758086,
#          'type': 2},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 115, 'gust': 4, 'speed': 1.99}}
# mount pleasant is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 48.1958, 'lon': -114.3129},
#  'dt': 1650769754,
#  'id': 5660340,
#  'main': {'feels_like': 40.05,
#           'humidity': 76,
#           'pressure': 1023,
#           'temp': 43.59,
#           'temp_max': 45.28,
#           'temp_min': 39.04},
#  'name': 'Kalispell',
#  'sys': {'country': 'US',
#          'id': 2021534,
#          'sunrise': 1650717124,
#          'sunset': 1650767919,
#          'type': 2},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 219, 'gust': 14, 'speed': 5.99}}
# kalispell is found
#
# {'base': 'stations',
#  'clouds': {'all': 91},
#  'cod': 200,
#  'coord': {'lat': 59.1433, 'lon': 68.8953},
#  'dt': 1650769755,
#  'id': 1487939,
#  'main': {'feels_like': 24.64,
#           'grnd_level': 1019,
#           'humidity': 69,
#           'pressure': 1025,
#           'sea_level': 1025,
#           'temp': 31.5,
#           'temp_max': 31.5,
#           'temp_min': 31.5},
#  'name': 'Uvat',
#  'sys': {'country': 'RU', 'sunrise': 1650757556, 'sunset': 1650812336},
#  'timezone': 18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 207, 'gust': 13.18, 'speed': 7.36}}
# uvat is found
#
# {'cod': '404', 'message': 'city not found'}
# city not found
#
# {'base': 'stations',
#  'clouds': {'all': 66},
#  'cod': 200,
#  'coord': {'lat': -34.5322, 'lon': 20.0403},
#  'dt': 1650769758,
#  'id': 1015776,
#  'main': {'feels_like': 51.91,
#           'grnd_level': 1008,
#           'humidity': 72,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 53.47,
#           'temp_max': 53.47,
#           'temp_min': 53.47},
#  'name': 'Bredasdorp',
#  'sys': {'country': 'ZA', 'sunrise': 1650776983, 'sunset': 1650816358},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 263, 'gust': 5.79, 'speed': 5.28}}
# bredasdorp is found
#
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': -20.7377, 'lon': 116.8463},
#  'dt': 1650769759,
#  'id': 6620339,
#  'main': {'feels_like': 87.53,
#           'grnd_level': 1009,
#           'humidity': 31,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 89.47,
#           'temp_max': 89.47,
#           'temp_min': 89.47},
#  'name': 'Karratha',
#  'sys': {'country': 'AU', 'sunrise': 1650752799, 'sunset': 1650794080},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 67, 'gust': 13.94, 'speed': 14.72}}
# karratha is found
#
# {'cod': '404', 'message': 'city not found'}
# city not found
#
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 64.8569, 'lon': -147.8028},
#  'dt': 1650769507,
#  'id': 5859699,
#  'main': {'feels_like': 47.41,
#           'humidity': 30,
#           'pressure': 1006,
#           'temp': 51.19,
#           'temp_max': 53.55,
#           'temp_min': 48.18},
#  'name': 'College',
#  'sys': {'country': 'US',
#          'id': 7683,
#          'sunrise': 1650721547,
#          'sunset': 1650779569,
#          'type': 1},
#  'timezone': -28800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 4.61}}
# college is found
#
# {'base': 'stations',
#  'clouds': {'all': 38},
#  'cod': 200,
#  'coord': {'lat': -33.65, 'lon': 115.3333},
#  'dt': 1650769763,
#  'id': 2075265,
#  'main': {'feels_like': 70.72,
#           'grnd_level': 1018,
#           'humidity': 45,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 71.73,
#           'temp_max': 71.73,
#           'temp_min': 71.73},
#  'name': 'Busselton',
#  'sys': {'country': 'AU', 'sunrise': 1650754032, 'sunset': 1650793573},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 38, 'gust': 12.15, 'speed': 9.19}}
# busselton is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -24.7911, 'lon': -50.0119},
#  'dt': 1650769764,
#  'id': 3466704,
#  'main': {'feels_like': 62.87,
#           'grnd_level': 904,
#           'humidity': 90,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 62.67,
#           'temp_max': 62.67,
#           'temp_min': 62.67},
#  'name': 'Castro',
#  'sys': {'country': 'BR', 'sunrise': 1650793111, 'sunset': 1650833851},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 256, 'gust': 1.97, 'speed': 1.74}}
# castro is found
#
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': -20.3667, 'lon': 14.9667},
#  'dt': 1650769766,
#  'id': 3356213,
#  'main': {'feels_like': 62.47,
#           'grnd_level': 904,
#           'humidity': 51,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 63.99,
#           'temp_max': 63.99,
#           'temp_min': 63.99},
#  'name': 'Khorixas',
#  'sys': {'country': 'NA', 'sunrise': 1650777233, 'sunset': 1650818542},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 202, 'gust': 2.93, 'speed': 2.82}}
# khorixas is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 71.6872, 'lon': 128.8694},
#  'dt': 1650769767,
#  'id': 2015306,
#  'main': {'feels_like': 2.17,
#           'grnd_level': 1009,
#           'humidity': 89,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 9.68,
#           'temp_max': 9.68,
#           'temp_min': 9.68},
#  'name': 'Tiksi',
#  'sys': {'country': 'RU', 'sunrise': 1650737706, 'sunset': 1650803402},
#  'timezone': 32400,
#  'visibility': 6643,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 102, 'gust': 4.43, 'speed': 4.07}}
# tiksi is found
#
# {'base': 'stations',
#  'clouds': {'all': 35},
#  'cod': 200,
#  'coord': {'lat': 65.282, 'lon': -126.8329},
#  'dt': 1650769769,
#  'id': 6089245,
#  'main': {'feels_like': 30.65,
#           'grnd_level': 1007,
#           'humidity': 91,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 36.73,
#           'temp_max': 36.73,
#           'temp_min': 36.73},
#  'name': 'Norman Wells',
#  'sys': {'country': 'CA', 'sunrise': 1650716368, 'sunset': 1650774684},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 112, 'gust': 18.03, 'speed': 7.92}}
# norman wells is found
#
# {'base': 'stations',
#  'clouds': {'all': 28},
#  'cod': 200,
#  'coord': {'lat': -19.0595, 'lon': -169.9187},
#  'dt': 1650769770,
#  'id': 4036284,
#  'main': {'feels_like': 79.86,
#           'grnd_level': 1001,
#           'humidity': 72,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 79.86,
#           'temp_max': 79.86,
#           'temp_min': 79.86},
#  'name': 'Alofi',
#  'rain': {'1h': 0.14},
#  'sys': {'country': 'NU', 'sunrise': 1650735118, 'sunset': 1650776613},
#  'timezone': -39600,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 171, 'gust': 5.88, 'speed': 6.64}}
# alofi is found
# {'base': 'stations',
#  'clouds': {'all': 70},
#  'cod': 200,
#  'coord': {'lat': -0.7393, 'lon': -90.3518},
#  'dt': 1650769771,
#  'id': 3652764,
#  'main': {'feels_like': 73.09,
#           'grnd_level': 1006,
#           'humidity': 91,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 71.92,
#           'temp_max': 71.92,
#           'temp_min': 71.92},
#  'name': 'Puerto Ayora',
#  'sys': {'country': 'EC', 'sunrise': 1650715007, 'sunset': 1650758536},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 131, 'gust': 7.58, 'speed': 5.97}}
# puerto ayora is found
#
# {'base': 'stations',
#  'clouds': {'all': 18},
#  'cod': 200,
#  'coord': {'lat': -8.9266, 'lon': 125.4092},
#  'dt': 1650769773,
#  'id': 1651810,
#  'main': {'feels_like': 74.46,
#           'grnd_level': 859,
#           'humidity': 43,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 75.22,
#           'temp_max': 75.22,
#           'temp_min': 75.22},
#  'name': 'Airai',
#  'sys': {'country': 'TL', 'sunrise': 1650750066, 'sunset': 1650792704},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 154, 'gust': 6.22, 'speed': 3.38}}
# airai is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 68.75, 'lon': 161.3},
#  'dt': 1650769774,
#  'id': 2126199,
#  'main': {'feels_like': 17.69,
#           'grnd_level': 1014,
#           'humidity': 77,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 22.19,
#           'temp_max': 22.19,
#           'temp_min': 22.19},
#  'name': 'Cherskiy',
#  'sys': {'country': 'RU', 'sunrise': 1650731969, 'sunset': 1650793575},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 305, 'gust': 2.51, 'speed': 3.33}}
# cherskiy is found
#
# {'base': 'stations',
#  'clouds': {'all': 18},
#  'cod': 200,
#  'coord': {'lat': -34.4187, 'lon': 19.2345},
#  'dt': 1650769776,
#  'id': 3366880,
#  'main': {'feels_like': 54.75,
#           'grnd_level': 1014,
#           'humidity': 67,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 56.28,
#           'temp_max': 56.28,
#           'temp_min': 56.28},
#  'name': 'Hermanus',
#  'sys': {'country': 'ZA', 'sunrise': 1650777168, 'sunset': 1650816560},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 317, 'gust': 2.86, 'speed': 2.8}}
# hermanus is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 59.7035, 'lon': 30.7861},
#  'dt': 1650769777,
#  'id': 546105,
#  'main': {'feels_like': 30.78,
#           'grnd_level': 1012,
#           'humidity': 83,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 37.33,
#           'temp_max': 37.87,
#           'temp_min': 35.78},
#  'name': 'Nikolskoye',
#  'sys': {'country': 'RU',
#          'id': 2034996,
#          'sunrise': 1650766548,
#          'sunset': 1650821635,
#          'type': 2},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 56, 'gust': 25.21, 'speed': 9.08}}
# nikolskoye is found
#
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 55.9029, 'lon': -3.5226},
#  'dt': 1650769667,
#  'id': 2644204,
#  'main': {'feels_like': 36.14,
#           'humidity': 90,
#           'pressure': 1017,
#           'temp': 42.48,
#           'temp_max': 44.47,
#           'temp_min': 39.79},
#  'name': 'Livingston',
#  'sys': {'country': 'GB',
#          'id': 1442,
#          'sunrise': 1650775610,
#          'sunset': 1650829040,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 11.5}}
# livingston is found
#
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -38.0023, 'lon': -57.5575},
#  'dt': 1650769520,
#  'id': 3430863,
#  'main': {'feels_like': 60.33,
#           'humidity': 78,
#           'pressure': 1003,
#           'temp': 60.87,
#           'temp_max': 60.87,
#           'temp_min': 59.02},
#  'name': 'Mar del Plata',
#  'rain': {'1h': 3.65},
#  'sys': {'country': 'AR',
#          'id': 2000296,
#          'sunrise': 1650795902,
#          'sunset': 1650834681,
#          'type': 2},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'thunderstorm',
#               'icon': '11n',
#               'id': 211,
#               'main': 'Thunderstorm'},
#              {'description': 'moderate rain',
#               'icon': '10n',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 320, 'speed': 11.5}}
# mar del plata is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 22.0752, 'lon': -159.319},
#  'dt': 1650769781,
#  'id': 5848280,
#  'main': {'feels_like': 77.25,
#           'humidity': 82,
#           'pressure': 1020,
#           'temp': 76.08,
#           'temp_max': 78.78,
#           'temp_min': 75.52},
#  'name': 'Kapaa',
#  'sys': {'country': 'US',
#          'id': 2001562,
#          'sunrise': 1650730246,
#          'sunset': 1650776398,
#          'type': 2},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 16.11}}
# kapaa is found
#
# {'base': 'stations',
#  'clouds': {'all': 69},
#  'cod': 200,
#  'coord': {'lat': 45.9339, 'lon': 133.7225},
#  'dt': 1650769782,
#  'id': 2025159,
#  'main': {'feels_like': 53.89,
#           'grnd_level': 996,
#           'humidity': 37,
#           'pressure': 1003,
#           'sea_level': 1003,
#           'temp': 56.77,
#           'temp_max': 56.77,
#           'temp_min': 56.77},
#  'name': 'Dalnerechensk',
#  'sys': {'country': 'RU', 'sunrise': 1650744249, 'sunset': 1650794530},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 280, 'gust': 25.3, 'speed': 18.3}}
# dalnerechensk is found
#
# {'base': 'stations',
#  'clouds': {'all': 63},
#  'cod': 200,
#  'coord': {'lat': 9.9658, 'lon': 98.6348},
#  'dt': 1650769784,
#  'id': 1150965,
#  'main': {'feels_like': 95.65,
#           'grnd_level': 1007,
#           'humidity': 61,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 88.02,
#           'temp_max': 88.02,
#           'temp_min': 88.02},
#  'name': 'Ranong',
#  'sys': {'country': 'TH', 'sunrise': 1650755455, 'sunset': 1650800165},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'gust': 3.94, 'speed': 1.52}}
# ranong is found
#
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': -22.2763, 'lon': 166.4572},
#  'dt': 1650769785,
#  'id': 2139521,
#  'main': {'feels_like': 79.05,
#           'humidity': 99,
#           'pressure': 1014,
#           'temp': 77,
#           'temp_max': 77,
#           'temp_min': 73.38},
#  'name': 'Noumea',
#  'sys': {'country': 'NC',
#          'id': 2018998,
#          'sunrise': 1650740984,
#          'sunset': 1650782085,
#          'type': 2},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 121, 'gust': 20.56, 'speed': 16.98}}
# noumea is found
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 33.7456, 'lon': -117.8678},
#  'dt': 1650769685,
#  'id': 5392900,
#  'main': {'feels_like': 64.63,
#           'humidity': 50,
#           'pressure': 1014,
#           'temp': 65.98,
#           'temp_max': 71.56,
#           'temp_min': 60.13},
#  'name': 'Santa Ana',
#  'sys': {'country': 'US',
#          'id': 2003506,
#          'sunrise': 1650719461,
#          'sunset': 1650767289,
#          'type': 2},
#  'timezone': -25200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 260, 'speed': 5.75}}
# santa ana is found
#
# {'cod': '404', 'message': 'city not found'}
# city not found
#
# {'base': 'stations',
#  'clouds': {'all': 67},
#  'cod': 200,
#  'coord': {'lat': -17.4759, 'lon': 24.2968},
#  'dt': 1650769789,
#  'id': 898905,
#  'main': {'feels_like': 63.66,
#           'grnd_level': 907,
#           'humidity': 66,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 64.42,
#           'temp_max': 64.42,
#           'temp_min': 64.42},
#  'name': 'Sesheke',
#  'sys': {'country': 'ZM', 'sunrise': 1650774821, 'sunset': 1650816477},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 59, 'gust': 3.38, 'speed': 3}}
# sesheke is found
#
# {'base': 'stations',
#  'clouds': {'all': 97},
#  'cod': 200,
#  'coord': {'lat': 66.0764, 'lon': 33.0381},
#  'dt': 1650769791,
#  'id': 533964,
#  'main': {'feels_like': 26.71,
#           'grnd_level': 1011,
#           'humidity': 96,
#           'pressure': 1022,
#           'sea_level': 1022,
#           'temp': 30.78,
#           'temp_max': 30.78,
#           'temp_min': 30.78},
#  'name': 'Loukhi',
#  'sys': {'country': 'RU', 'sunrise': 1650763952, 'sunset': 1650823150},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 243, 'gust': 9.06, 'speed': 3.96}}
# loukhi is found
#
# {'base': 'stations',
#  'clouds': {'all': 97},
#  'cod': 200,
#  'coord': {'lat': -46.1927, 'lon': 168.8643},
#  'dt': 1650769792,
#  'id': 6201424,
#  'main': {'feels_like': 52.75,
#           'grnd_level': 1004,
#           'humidity': 90,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 53.47,
#           'temp_max': 53.47,
#           'temp_min': 53.47},
#  'name': 'Mataura',
#  'sys': {'country': 'NZ',
#          'id': 2008959,
#          'sunrise': 1650742313,
#          'sunset': 1650779601,
#          'type': 2},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'gust': 24.81, 'speed': 8.99}}
# mataura is found
#
# {'base': 'stations',
#  'clouds': {'all': 91},
#  'cod': 200,
#  'coord': {'lat': 58.8053, 'lon': -122.7002},
#  'dt': 1650769793,
#  'id': 5955902,
#  'main': {'feels_like': 36.21,
#           'grnd_level': 969,
#           'humidity': 100,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 36.21,
#           'temp_max': 36.21,
#           'temp_min': 36.21},
#  'name': 'Fort Nelson',
#  'sys': {'country': 'CA', 'sunrise': 1650717295, 'sunset': 1650771773},
#  'timezone': -25200,
#  'visibility': 100,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 345, 'gust': 2.26, 'speed': 2.35}}
# fort nelson is found
#
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': 12.0564, 'lon': -61.7485},
#  'dt': 1650769795,
#  'id': 3579925,
#  'main': {'feels_like': 78.1,
#           'grnd_level': 1009,
#           'humidity': 76,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 77.11,
#           'temp_max': 77.11,
#           'temp_min': 77.11},
#  'name': "St. George's",
#  'sys': {'country': 'GD', 'sunrise': 1650707443, 'sunset': 1650752372},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'gust': 15.9, 'speed': 11.74}}
# saint-georges is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -7.8614, 'lon': -38.7597},
#  'dt': 1650769796,
#  'id': 3388440,
#  'main': {'feels_like': 71.69,
#           'grnd_level': 958,
#           'humidity': 85,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 70.9,
#           'temp_max': 70.9,
#           'temp_min': 70.9},
#  'name': 'São José do Belmonte',
#  'sys': {'country': 'BR', 'sunrise': 1650789409, 'sunset': 1650832153},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 109, 'gust': 4.25, 'speed': 3.36}}
# sao jose do belmonte is found
#
# {'base': 'stations',
#  'clouds': {'all': 52},
#  'cod': 200,
#  'coord': {'lat': 55.0709, 'lon': 57.5485},
#  'dt': 1650769798,
#  'id': 580660,
#  'main': {'feels_like': 43.97,
#           'grnd_level': 999,
#           'humidity': 64,
#           'pressure': 1022,
#           'sea_level': 1022,
#           'temp': 43.97,
#           'temp_max': 43.97,
#           'temp_min': 43.97},
#  'name': 'Minyar',
#  'sys': {'country': 'RU', 'sunrise': 1650761136, 'sunset': 1650814203},
#  'timezone': 18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 153, 'gust': 2.35, 'speed': 1.57}}
# minyar is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 42.6001, 'lon': -73.9662},
#  'dt': 1650769799,
#  'id': 5106841,
#  'main': {'feels_like': 46.58,
#           'humidity': 57,
#           'pressure': 1023,
#           'temp': 46.58,
#           'temp_max': 48.63,
#           'temp_min': 42.89},
#  'name': 'Albany',
#  'sys': {'country': 'US',
#          'id': 19530,
#          'sunrise': 1650708113,
#          'sunset': 1650757566,
#          'type': 2},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 21, 'gust': 3.6, 'speed': 2.01}}
# albany is found
#
# {'base': 'stations',
#  'clouds': {'all': 23},
#  'cod': 200,
#  'coord': {'lat': -33.5906, 'lon': 26.891},
#  'dt': 1650769801,
#  'id': 964432,
#  'main': {'feels_like': 58.21,
#           'humidity': 96,
#           'pressure': 1012,
#           'temp': 58.17,
#           'temp_max': 58.17,
#           'temp_min': 58.17},
#  'name': 'Port Alfred',
#  'sys': {'country': 'ZA',
#          'id': 2072861,
#          'sunrise': 1650775265,
#          'sunset': 1650814788,
#          'type': 2},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 273, 'gust': 11.41, 'speed': 10.38}}
# port alfred is found
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -43.3002, 'lon': -65.1023},
#  'dt': 1650769802,
#  'id': 3839307,
#  'main': {'feels_like': 53.65,
#           'grnd_level': 991,
#           'humidity': 41,
#           'pressure': 992,
#           'sea_level': 992,
#           'temp': 56.39,
#           'temp_max': 56.39,
#           'temp_min': 56.39},
#  'name': 'Rawson',
#  'sys': {'country': 'AR', 'sunrise': 1650798208, 'sunset': 1650835996},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 294, 'gust': 31.56, 'speed': 19.6}}
# rawson is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 71.2906, 'lon': -156.7887},
#  'dt': 1650769804,
#  'id': 5880054,
#  'main': {'feels_like': 7.21,
#           'humidity': 86,
#           'pressure': 1014,
#           'temp': 15.82,
#           'temp_max': 15.82,
#           'temp_min': 15.82},
#  'name': 'Barrow',
#  'sys': {'country': 'US',
#          'id': 7649,
#          'sunrise': 1650720267,
#          'sunset': 1650785162,
#          'type': 1},
#  'timezone': -28800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 100, 'speed': 5.75}}
# barrow is found
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 25.0213, 'lon': 37.2685},
#  'dt': 1650769805,
#  'id': 100926,
#  'main': {'feels_like': 75.58,
#           'grnd_level': 1005,
#           'humidity': 79,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 74.7,
#           'temp_max': 74.7,
#           'temp_min': 74.7},
#  'name': 'Umluj',
#  'sys': {'country': 'SA', 'sunrise': 1650769247, 'sunset': 1650815825},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 340, 'gust': 2.53, 'speed': 2.37}}
# umm lajj is found
# {'base': 'stations',
#  'clouds': {'all': 11},
#  'cod': 200,
#  'coord': {'lat': -17.7125, 'lon': -39.2481},
#  'dt': 1650769806,
#  'id': 3466980,
#  'main': {'feels_like': 78.21,
#           'grnd_level': 1014,
#           'humidity': 95,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 76.41,
#           'temp_max': 76.41,
#           'temp_min': 76.41},
#  'name': 'Caravelas',
#  'sys': {'country': 'BR', 'sunrise': 1650790088, 'sunset': 1650831707},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 34, 'gust': 15.7, 'speed': 5.44}}
# caravelas is found
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 51.3674, 'lon': 110.4676},
#  'dt': 1650769808,
#  'id': 2022463,
#  'main': {'feels_like': 28.22,
#           'grnd_level': 912,
#           'humidity': 22,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 37.04,
#           'temp_max': 37.04,
#           'temp_min': 37.04},
#  'name': 'Khilok',
#  'sys': {'country': 'RU', 'sunrise': 1650749082, 'sunset': 1650800858},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 292, 'gust': 24.67, 'speed': 14.45}}
# khilok is found
#
# {'base': 'stations',
#  'clouds': {'all': 97},
#  'cod': 200,
#  'coord': {'lat': 58.655, 'lon': 27.1592},
#  'dt': 1650769809,
#  'id': 591703,
#  'main': {'feels_like': 27.72,
#           'grnd_level': 1006,
#           'humidity': 91,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 37.29,
#           'temp_max': 39.43,
#           'temp_min': 37.29},
#  'name': 'Kallaste',
#  'sys': {'country': 'EE',
#          'id': 2038091,
#          'sunrise': 1650767670,
#          'sunset': 1650822254,
#          'type': 2},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 40, 'gust': 28.25, 'speed': 17.11}}
# kallaste is found
#
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': 42.2386, 'lon': -1.764},
#  'dt': 1650769811,
#  'id': 6359717,
#  'main': {'feels_like': 48.63,
#           'grnd_level': 973,
#           'humidity': 68,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 50.67,
#           'temp_max': 50.67,
#           'temp_min': 50.67},
#  'name': 'Milagro',
#  'sys': {'country': 'ES',
#          'id': 6407,
#          'sunrise': 1650777151,
#          'sunset': 1650826654,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'gust': 29.37, 'speed': 14.9}}
# milagro is found
#
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': 14.4, 'lon': 46.4667},
#  'dt': 1650769812,
#  'id': 72181,
#  'main': {'feels_like': 67.6,
#           'grnd_level': 887,
#           'humidity': 45,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 68.9,
#           'temp_max': 68.9,
#           'temp_min': 68.9},
#  'name': 'Marzuq',
#  'sys': {'country': 'YE', 'sunrise': 1650767714, 'sunset': 1650812943},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 187, 'gust': 4.74, 'speed': 5.03}}
# marzuq is found
#
# {'base': 'stations',
#  'clouds': {'all': 6},
#  'cod': 200,
#  'coord': {'lat': 36.3868, 'lon': 4.3989},
#  'dt': 1650769814,
#  'id': 2477537,
#  'main': {'feels_like': 50.77,
#           'grnd_level': 976,
#           'humidity': 62,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 52.88,
#           'temp_max': 52.88,
#           'temp_min': 52.88},
#  'name': 'Tazmalt',
#  'sys': {'country': 'DZ', 'sunrise': 1650776245, 'sunset': 1650824603},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 216, 'gust': 2.04, 'speed': 1.41}}
# tazmalt is found
#
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -42.8794, 'lon': 147.3294},
#  'dt': 1650769566,
#  'id': 2163355,
#  'main': {'feels_like': 63.48,
#           'humidity': 55,
#           'pressure': 1028,
#           'temp': 64.72,
#           'temp_max': 65.23,
#           'temp_min': 64.26},
#  'name': 'Hobart',
#  'sys': {'country': 'AU',
#          'id': 2002195,
#          'sunrise': 1650747142,
#          'sunset': 1650785107,
#          'type': 2},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'speed': 5.75}}
# hobart is found
#
# {'base': 'stations',
#  'clouds': {'all': 60},
#  'cod': 200,
#  'coord': {'lat': 25.9551, 'lon': 68.8882},
#  'dt': 1650769702,
#  'id': 1175762,
#  'main': {'feels_like': 89.87,
#           'grnd_level': 1005,
#           'humidity': 20,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 93.52,
#           'temp_max': 93.52,
#           'temp_min': 93.52},
#  'name': 'Jhol',
#  'sys': {'country': 'PK', 'sunrise': 1650761598, 'sunset': 1650808299},
#  'timezone': 18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 278, 'gust': 4.43, 'speed': 2.48}}
# jhol is found
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -20.3297, 'lon': -40.2925},
#  'dt': 1650769818,
#  'id': 3445026,
#  'main': {'feels_like': 78.94,
#           'humidity': 86,
#           'pressure': 1013,
#           'temp': 78.94,
#           'temp_max': 78.94,
#           'temp_min': 78.75},
#  'name': 'Vila Velha',
#  'sys': {'country': 'BR',
#          'id': 2012383,
#          'sunrise': 1650790497,
#          'sunset': 1650831800,
#          'type': 2},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 30, 'speed': 13.8}}
# vila velha is found
#
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -54.8, 'lon': -68.3},
#  'dt': 1650769715,
#  'id': 3833367,
#  'main': {'feels_like': 34.3,
#           'humidity': 81,
#           'pressure': 982,
#           'temp': 40.66,
#           'temp_max': 40.66,
#           'temp_min': 40.66},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 8303,
#          'sunrise': 1650800447,
#          'sunset': 1650835292,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 20, 'speed': 10.36}}
# ushuaia is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 19.7297, 'lon': -155.09},
#  'dt': 1650769820,
#  'id': 5855927,
#  'main': {'feels_like': 76.1,
#           'humidity': 81,
#           'pressure': 1019,
#           'temp': 75.09,
#           'temp_max': 79.29,
#           'temp_min': 73.11},
#  'name': 'Hilo',
#  'sys': {'country': 'US',
#          'id': 7881,
#          'sunrise': 1650729380,
#          'sunset': 1650775233,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 90, 'speed': 9.22}}
# hilo is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 32.5, 'lon': 130.6},
#  'dt': 1650769822,
#  'id': 1848445,
#  'main': {'feels_like': 65.48,
#           'grnd_level': 1010,
#           'humidity': 96,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 64.8,
#           'temp_max': 64.8,
#           'temp_min': 64.8},
#  'name': 'Honmachi',
#  'rain': {'1h': 0.42},
#  'sys': {'country': 'JP',
#          'id': 8006,
#          'sunrise': 1650746309,
#          'sunset': 1650793970,
#          'type': 1},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 81, 'gust': 4.29, 'speed': 3.09}}
# yatsushiro is found
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': 73.5069, 'lon': 80.5464},
#  'dt': 1650769823,
#  'id': 1507390,
#  'main': {'feels_like': -9.38,
#           'grnd_level': 1006,
#           'humidity': 95,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 3.22,
#           'temp_max': 3.22,
#           'temp_min': 3.22},
#  'name': 'Dikson',
#  'sys': {'country': 'RU', 'sunrise': 1650747379, 'sunset': 1650816922},
#  'timezone': 25200,
#  'visibility': 8181,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 202, 'gust': 18.7, 'speed': 13.44}}
# dikson is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 50.6996, 'lon': -127.4199},
#  'dt': 1650769825,
#  'id': 6111862,
#  'main': {'feels_like': 39.56,
#           'grnd_level': 1020,
#           'humidity': 87,
#           'pressure': 1020,
#           'sea_level': 1020,
#           'temp': 45.91,
#           'temp_max': 45.91,
#           'temp_min': 45.91},
#  'name': 'Port Hardy',
#  'sys': {'country': 'CA', 'sunrise': 1650719916, 'sunset': 1650771417},
#  'timezone': -25200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 140, 'gust': 26.6, 'speed': 14.45}}
# port hardy is found
#
# {'base': 'stations',
#  'clouds': {'all': 60},
#  'cod': 200,
#  'coord': {'lat': -9.8, 'lon': -139.0333},
#  'dt': 1650769826,
#  'id': 4020109,
#  'main': {'feels_like': 79.45,
#           'grnd_level': 1003,
#           'humidity': 77,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 79.45,
#           'temp_max': 79.45,
#           'temp_min': 79.45},
#  'name': 'Atuona',
#  'sys': {'country': 'PF', 'sunrise': 1650727179, 'sunset': 1650769728},
#  'timezone': -34200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 99, 'gust': 17.45, 'speed': 16.69}}
# atuona is found
#
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -53.15, 'lon': -70.9167},
#  'dt': 1650769827,
#  'id': 3874787,
#  'main': {'feels_like': 42.91,
#           'humidity': 93,
#           'pressure': 980,
#           'temp': 42.91,
#           'temp_max': 42.91,
#           'temp_min': 42.12},
#  'name': 'Punta Arenas',
#  'rain': {'1h': 1.16},
#  'sys': {'country': 'CL',
#          'id': 8487,
#          'sunrise': 1650800815,
#          'sunset': 1650836179,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10n',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 30, 'speed': 1.14}}
# punta arenas is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -16.2325, 'lon': 39.9086},
#  'dt': 1650769829,
#  'id': 1052944,
#  'main': {'feels_like': 76.51,
#           'grnd_level': 1006,
#           'humidity': 92,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 74.98,
#           'temp_max': 74.98,
#           'temp_min': 74.98},
#  'name': 'Angoche',
#  'sys': {'country': 'MZ', 'sunrise': 1650771000, 'sunset': 1650812805},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 318, 'gust': 26.6, 'speed': 16.69}}
# angoche is found
#
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 5.4112, 'lon': 100.3354},
#  'dt': 1650769830,
#  'id': 1735106,
#  'main': {'feels_like': 96.67,
#           'humidity': 74,
#           'pressure': 1009,
#           'temp': 85.93,
#           'temp_max': 85.95,
#           'temp_min': 85.93},
#  'name': 'George Town',
#  'sys': {'country': 'MY',
#          'id': 9438,
#          'sunrise': 1650755302,
#          'sunset': 1650799502,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 8000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'speed': 4.61}}
# georgetown is found
#
# {'base': 'stations',
#  'clouds': {'all': 17},
#  'cod': 200,
#  'coord': {'lat': 71.9167, 'lon': 114.0833},
#  'dt': 1650769832,
#  'id': 2017155,
#  'main': {'feels_like': 0.63,
#           'grnd_level': 1013,
#           'humidity': 88,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 8.98,
#           'temp_max': 8.98,
#           'temp_min': 8.98},
#  'name': 'Saskylakh',
#  'sys': {'country': 'RU', 'sunrise': 1650741039, 'sunset': 1650807166},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 182, 'gust': 6.17, 'speed': 4.56}}
# saskylakh is found
#
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -46.6, 'lon': 168.3333},
#  'dt': 1650769833,
#  'id': 2206939,
#  'main': {'feels_like': 51.84,
#           'grnd_level': 1008,
#           'humidity': 63,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 53.8,
#           'temp_max': 53.8,
#           'temp_min': 53.8},
#  'name': 'Bluff',
#  'sys': {'country': 'NZ',
#          'id': 2008959,
#          'sunrise': 1650742486,
#          'sunset': 1650779683,
#          'type': 2},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 245, 'gust': 30.74, 'speed': 24.2}}
# bluff is found
#
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': -30.5472, 'lon': 29.4241},
#  'dt': 1650769835,
#  'id': 988356,
#  'main': {'feels_like': 50.43,
#           'grnd_level': 869,
#           'humidity': 96,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 51.12,
#           'temp_max': 51.12,
#           'temp_min': 51.12},
#  'name': 'Kokstad',
#  'sys': {'country': 'ZA', 'sunrise': 1650774432, 'sunset': 1650814405},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 313, 'gust': 3.67, 'speed': 3.78}}
# kokstad is found
#
# {'base': 'stations',
#  'clouds': {'all': 78},
#  'cod': 200,
#  'coord': {'lat': 70.6333, 'lon': 147.9167},
#  'dt': 1650769836,
#  'id': 2126123,
#  'main': {'feels_like': 4.96,
#           'grnd_level': 1011,
#           'humidity': 89,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 4.96,
#           'temp_max': 4.96,
#           'temp_min': 4.96},
#  'name': 'Chokurdakh',
#  'sys': {'country': 'RU', 'sunrise': 1650733979, 'sunset': 1650797988},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 271, 'gust': 3.18, 'speed': 2.84}}
# chokurdakh is found
#
# {'base': 'stations',
#  'clouds': {'all': 77},
#  'cod': 200,
#  'coord': {'lat': -3.1374, 'lon': 142.3475},
#  'dt': 1650769838,
#  'id': 2101169,
#  'main': {'feels_like': 93.47,
#           'grnd_level': 1007,
#           'humidity': 67,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 85.86,
#           'temp_max': 85.86,
#           'temp_min': 85.86},
#  'name': 'Aitape',
#  'sys': {'country': 'PG', 'sunrise': 1650745686, 'sunset': 1650788955},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 52, 'gust': 7.14, 'speed': 7.31}}
# aitape is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -46.1333, 'lon': 167.6833},
#  'dt': 1650769839,
#  'id': 2180815,
#  'main': {'feels_like': 48.87,
#           'grnd_level': 1009,
#           'humidity': 76,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 50.54,
#           'temp_max': 50.54,
#           'temp_min': 50.54},
#  'name': 'Tuatapere',
#  'sys': {'country': 'NZ', 'sunrise': 1650742590, 'sunset': 1650779890},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 244, 'gust': 23.02, 'speed': 12.84}}
# tuatapere is found
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 42.097, 'lon': -79.2353},
#  'dt': 1650769566,
#  'id': 5122534,
#  'main': {'feels_like': 61.77,
#           'humidity': 56,
#           'pressure': 1019,
#           'temp': 63.12,
#           'temp_max': 67.64,
#           'temp_min': 49.59},
#  'name': 'Jamestown',
#  'sys': {'country': 'US',
#          'id': 2008933,
#          'sunrise': 1650709429,
#          'sunset': 1650758779,
#          'type': 2},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 160, 'speed': 6.91}}
# jamestown is found
#
# {'base': 'stations',
#  'clouds': {'all': 15},
#  'cod': 200,
#  'coord': {'lat': 19.5049, 'lon': 99.9924},
#  'dt': 1650769842,
#  'id': 1608068,
#  'main': {'feels_like': 91.58,
#           'grnd_level': 966,
#           'humidity': 42,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 90.14,
#           'temp_max': 96.19,
#           'temp_min': 89.01},
#  'name': 'Pa Daet',
#  'sys': {'country': 'TH',
#          'id': 2038631,
#          'sunrise': 1650754563,
#          'sunset': 1650800405,
#          'type': 2},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 181, 'gust': 6.46, 'speed': 3.85}}
# pa daet is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 51.5877, 'lon': -2.9984},
#  'dt': 1650769563,
#  'id': 2641598,
#  'main': {'feels_like': 45.34,
#           'humidity': 79,
#           'pressure': 1001,
#           'temp': 48.04,
#           'temp_max': 49.77,
#           'temp_min': 46.33},
#  'name': 'Newport',
#  'sys': {'country': 'GB',
#          'id': 2043389,
#          'sunrise': 1650776242,
#          'sunset': 1650828156,
#          'type': 2},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 289, 'gust': 10, 'speed': 5.99}}
# newport is found
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -29.6842, 'lon': -53.8069},
#  'dt': 1650769844,
#  'id': 3450083,
#  'main': {'feels_like': 51.33,
#           'grnd_level': 996,
#           'humidity': 80,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 52.61,
#           'temp_max': 52.61,
#           'temp_min': 52.61},
#  'name': 'Santa Maria',
#  'sys': {'country': 'BR', 'sunrise': 1650794354, 'sunset': 1650834429},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 48, 'gust': 3.83, 'speed': 3.94}}
# santa maria is found
#
# {'base': 'stations',
#  'clouds': {'all': 31},
#  'cod': 200,
#  'coord': {'lat': 7.9803, 'lon': 49.8164},
#  'dt': 1650769846,
#  'id': 60019,
#  'main': {'feels_like': 86.9,
#           'grnd_level': 1006,
#           'humidity': 73,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 81.9,
#           'temp_max': 81.9,
#           'temp_min': 81.9},
#  'name': 'Eyl',
#  'sys': {'country': 'SO', 'sunrise': 1650767280, 'sunset': 1650811769},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 87, 'gust': 9.46, 'speed': 6.64}}
# eyl is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 60.7167, 'lon': -46.0333},
#  'dt': 1650769847,
#  'id': 3420846,
#  'main': {'feels_like': 32.5,
#           'grnd_level': 1032,
#           'humidity': 99,
#           'pressure': 1032,
#           'sea_level': 1032,
#           'temp': 35.89,
#           'temp_max': 35.89,
#           'temp_min': 35.89},
#  'name': 'Qaqortoq',
#  'rain': {'1h': 0.47},
#  'sys': {'country': 'GL', 'sunrise': 1650784685, 'sunset': 1650840367},
#  'timezone': -7200,
#  'visibility': 157,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 11, 'gust': 5.46, 'speed': 4.07}}
# qaqortoq is found
#
# {'base': 'stations',
#  'clouds': {'all': 98},
#  'cod': 200,
#  'coord': {'lat': -3.3667, 'lon': 135.4833},
#  'dt': 1650769849,
#  'id': 1634614,
#  'main': {'feels_like': 93.65,
#           'grnd_level': 1006,
#           'humidity': 61,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 87.08,
#           'temp_max': 87.08,
#           'temp_min': 87.08},
#  'name': 'Nabire',
#  'sys': {'country': 'ID', 'sunrise': 1650747345, 'sunset': 1650790589},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 325, 'gust': 3.33, 'speed': 4.38}}
# nabire is found
#
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
# ...
#           'temp_max': 34.5,
#           'temp_min': 34.5},
#  'name': 'Vitim',
#  'snow': {'1h': 0.12},
#  'sys': {'country': 'RU', 'sunrise': 1650747023, 'sunset': 1650801914},
#  'timezone': 32400,
#  'visibility': 6114,
#  'weather': [{'description': 'light snow',
#               'icon': '13d',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 246, 'gust': 5.06, 'speed': 3.22}}
# vitim is found
#
# {'base': 'stations',
#  'clouds': {'all': 89},
#  'cod': 200,
#  'coord': {'lat': -20.4872, 'lon': 57.4656},
#  'dt': 1650770623,
#  'id': 934614,
#  'main': {'feels_like': 75.11,
#           'grnd_level': 1008,
#           'humidity': 67,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 74.79,
#           'temp_max': 74.79,
#           'temp_min': 74.79},
#  'name': 'Chemin Grenier',
#  'sys': {'country': 'MU',
#          'id': 2061,
#          'sunrise': 1650767039,
#          'sunset': 1650808340,
#          'type': 1},
#  'timezone': 14400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 109, 'gust': 21.05, 'speed': 13.51}}
# chemin grenier is found
#
# {'base': 'stations',
#  'clouds': {'all': 98},
#  'cod': 200,
#  'coord': {'lat': -1.195, 'lon': -46.02},
#  'dt': 1650770624,
#  'id': 3402648,
#  'main': {'feels_like': 74.7,
#           'grnd_level': 1012,
#           'humidity': 96,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 73.17,
#           'temp_max': 73.17,
#           'temp_min': 73.17},
#  'name': 'Carutapera',
#  'sys': {'country': 'BR', 'sunrise': 1650790784, 'sunset': 1650834262},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 169, 'gust': 7.54, 'speed': 4.14}}
# carutapera is found
#
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 68.3499, 'lon': -133.7218},
#  'dt': 1650770626,
#  'id': 5983607,
#  'main': {'feels_like': 38.97,
#           'humidity': 38,
#           'pressure': 1015,
#           'temp': 41.86,
#           'temp_max': 41.86,
#           'temp_min': 41.76},
#  'name': 'Inuvik',
#  'sys': {'country': 'CA',
#          'id': 1029,
#          'sunrise': 1650716641,
#          'sunset': 1650777717,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 200, 'speed': 4.61}}
# inuvik is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 34.6667, 'lon': 138.95},
#  'dt': 1650770627,
#  'id': 1852357,
#  'main': {'feels_like': 65.41,
#           'grnd_level': 1015,
#           'humidity': 95,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 64.76,
#           'temp_max': 64.76,
#           'temp_min': 64.76},
#  'name': 'Shimoda',
#  'rain': {'1h': 0.42},
#  'sys': {'country': 'JP',
#          'id': 8070,
#          'sunrise': 1650744128,
#          'sunset': 1650792142,
#          'type': 1},
#  'timezone': 32400,
#  'visibility': 5170,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 43, 'gust': 13.94, 'speed': 11.72}}
# shimoda is found
#
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 65.6835, 'lon': -18.0878},
#  'dt': 1650770628,
#  'id': 2633274,
#  'main': {'feels_like': 31.93,
#           'humidity': 93,
#           'pressure': 1032,
#           'temp': 31.93,
#           'temp_max': 31.93,
#           'temp_min': 31.93},
#  'name': 'Akureyri',
#  'sys': {'country': 'IS',
#          'id': 83,
#          'sunrise': 1650776352,
#          'sunset': 1650835288,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 900,
#  'weather': [{'description': 'fog', 'icon': '50n', 'id': 741, 'main': 'Fog'}],
#  'wind': {'deg': 0, 'speed': 0}}
# akureyri is found
# {'base': 'stations',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': 24.1833, 'lon': 83.8167},
#  'dt': 1650770630,
#  'id': 1271493,
#  'main': {'feels_like': 91.56,
#           'grnd_level': 984,
#           'humidity': 13,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 96.21,
#           'temp_max': 96.21,
#           'temp_min': 96.21},
#  'name': 'Garhwa',
#  'sys': {'country': 'IN', 'sunrise': 1650758138, 'sunset': 1650804593},
#  'timezone': 19800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 215, 'gust': 3.67, 'speed': 3.74}}
# garwa is found
#
# {'base': 'stations',
#  'clouds': {'all': 49},
#  'cod': 200,
#  'coord': {'lat': 45.6542, 'lon': 41.199},
#  'dt': 1650770631,
#  'id': 519106,
#  'main': {'feels_like': 45.05,
#           'grnd_level': 998,
#           'humidity': 68,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 49.42,
#           'temp_max': 49.42,
#           'temp_min': 49.42},
#  'name': 'Gorkovskiy',
#  'sys': {'country': 'RU', 'sunrise': 1650766463, 'sunset': 1650816722},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 102, 'gust': 26.57, 'speed': 10.83}}
# gorkovskiy is found
#
# {'base': 'stations',
#  'clouds': {'all': 85},
#  'cod': 200,
#  'coord': {'lat': 67.4667, 'lon': 86.5833},
#  'dt': 1650770633,
#  'id': 1505991,
#  'main': {'feels_like': 1.65,
#           'grnd_level': 1013,
#           'humidity': 89,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 11.61,
#           'temp_max': 11.61,
#           'temp_min': 11.61},
#  'name': 'Igarka',
#  'sys': {'country': 'RU', 'sunrise': 1650750511, 'sunset': 1650810893},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 313, 'gust': 7.47, 'speed': 6.26}}
# igarka is found
#
# {'base': 'stations',
#  'clouds': {'all': 98},
#  'cod': 200,
#  'coord': {'lat': 69.4058, 'lon': 86.1778},
#  'dt': 1650770634,
#  'id': 1507116,
#  'main': {'feels_like': 1.62,
#           'grnd_level': 1011,
#           'humidity': 96,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 1.62,
#           'temp_max': 1.62,
#           'temp_min': 1.62},
#  'name': 'Dudinka',
#  'sys': {'country': 'RU',
#          'id': 49144,
#          'sunrise': 1650749554,
#          'sunset': 1650812044,
#          'type': 2},
#  'timezone': 25200,
#  'visibility': 8655,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 314, 'gust': 2.91, 'speed': 2.89}}
# dudinka is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 60.3778, 'lon': 92.6267},
#  'dt': 1650770636,
#  'id': 1489656,
#  'main': {'feels_like': 23.61,
#           'grnd_level': 990,
#           'humidity': 88,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 28.18,
#           'temp_max': 28.18,
#           'temp_min': 28.18},
#  'name': 'Teya',
#  'sys': {'country': 'RU', 'sunrise': 1650751564, 'sunset': 1650806939},
#  'timezone': 25200,
#  'visibility': 1495,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 287, 'gust': 6.58, 'speed': 4.05}}
# teya is found
#
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 39.05, 'lon': -27.9833},
#  'dt': 1650770637,
#  'id': 3372964,
#  'main': {'feels_like': 56.07,
#           'grnd_level': 999,
#           'humidity': 68,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 57.43,
#           'temp_max': 57.43,
#           'temp_min': 57.43},
#  'name': 'Lagoa',
#  'sys': {'country': 'PT', 'sunrise': 1650783762, 'sunset': 1650832627},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 296, 'gust': 26.17, 'speed': 24.05}}
# lagoa is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 61.2767, 'lon': 108.0108},
#  'dt': 1650770639,
#  'id': 2012956,
#  'main': {'feels_like': 27.75,
#           'grnd_level': 977,
#           'humidity': 60,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 31.41,
#           'temp_max': 31.41,
#           'temp_min': 31.41},
#  'name': 'Yerbogachën',
#  'sys': {'country': 'RU', 'sunrise': 1650747638, 'sunset': 1650803482},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'gust': 3.58, 'speed': 3.69}}
# yerbogachen is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 51.1983, 'lon': 136.6669},
#  'dt': 1650770640,
#  'id': 2023943,
#  'main': {'feels_like': 24.67,
#           'grnd_level': 986,
#           'humidity': 99,
#           'pressure': 994,
#           'sea_level': 994,
#           'temp': 32.38,
#           'temp_max': 32.38,
#           'temp_min': 32.38},
#  'name': 'Gorin',
#  'snow': {'1h': 1.38},
#  'sys': {'country': 'RU', 'sunrise': 1650742829, 'sunset': 1650794537},
#  'timezone': 36000,
#  'visibility': 76,
#  'weather': [{'description': 'snow', 'icon': '13d', 'id': 601, 'main': 'Snow'}],
#  'wind': {'deg': 325, 'gust': 18.43, 'speed': 9.1}}
# gorin is found
#
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
#  'coord': {'lat': 45.1667, 'lon': 10.7833},
#  'dt': 1650770642,
#  'id': 3174050,
#  'main': {'feels_like': 49.06,
#           'humidity': 84,
#           'pressure': 1004,
#           'temp': 50.38,
#           'temp_max': 54.55,
#           'temp_min': 47.08},
#  'name': 'Province of Mantua',
#  'sys': {'country': 'IT',
#          'id': 2011529,
#          'sunrise': 1650773813,
#          'sunset': 1650823970,
#          'type': 2},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 183, 'gust': 3, 'speed': 3}}
# mantua is found
#
# {'base': 'stations',
#  'clouds': {'all': 57},
#  'cod': 200,
#  'coord': {'lat': -9.4333, 'lon': 159.95},
#  'dt': 1650770643,
#  'id': 2108502,
#  'main': {'feels_like': 94.59,
#           'grnd_level': 1004,
#           'humidity': 63,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 87.12,
#           'temp_max': 87.12,
#           'temp_min': 87.12},
#  'name': 'Honiara',
#  'sys': {'country': 'SB', 'sunrise': 1650741804, 'sunset': 1650784388},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 24, 'gust': 4.76, 'speed': 4.32}}
# honiara is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 42.2506, 'lon': -75.833},
#  'dt': 1650770645,
#  'id': 5110365,
#  'main': {'feels_like': 49.53,
#           'humidity': 67,
#           'pressure': 1007,
#           'temp': 51.53,
#           'temp_max': 54.63,
#           'temp_min': 47.17},
#  'name': 'Broome',
#  'sys': {'country': 'US',
#          'id': 2036074,
#          'sunrise': 1650708597,
#          'sunset': 1650757978,
#          'type': 2},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'speed': 5.75}}
# broome is found
#
# {'base': 'stations',
#  'clouds': {'all': 98},
#  'cod': 200,
#  'coord': {'lat': 65.7, 'lon': 82.4667},
#  'dt': 1650770646,
#  'id': 1502073,
#  'main': {'feels_like': -2.72,
#           'grnd_level': 1017,
#           'humidity': 91,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 9.27,
#           'temp_max': 9.27,
#           'temp_min': 9.27},
#  'name': "Krasnosel'kup",
#  'sys': {'country': 'RU', 'sunrise': 1650752277, 'sunset': 1650811103},
#  'timezone': 18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 301, 'gust': 9.89, 'speed': 7.87}}
# krasnoselkup is found
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 66.0317, 'lon': 60.1659},
#  'dt': 1650770647,
#  'id': 1505579,
#  'main': {'feels_like': 12.16,
#           'grnd_level': 1012,
#           'humidity': 85,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 17.47,
#           'temp_max': 17.47,
#           'temp_min': 17.47},
#  'name': 'Inta',
#  'sys': {'country': 'RU', 'sunrise': 1650757478, 'sunset': 1650816604},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 26, 'gust': 3.15, 'speed': 3.42}}
# inta is found
#
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': 66.4167, 'lon': 112.4},
#  'dt': 1650770649,
#  'id': 2014624,
#  'main': {'feels_like': 15.84,
#           'grnd_level': 977,
#           'humidity': 67,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 21.45,
#           'temp_max': 21.45,
#           'temp_min': 21.45},
#  'name': 'Udachny',
#  'sys': {'country': 'RU',
#          'id': 49565,
#          'sunrise': 1650744813,
#          'sunset': 1650804200,
#          'type': 2},
#  'timezone': 32400,
#  'visibility': 9413,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 48, 'gust': 3.6, 'speed': 4.05}}
# udachnyy is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 1.1983, 'lon': -70.1733},
#  'dt': 1650770650,
#  'id': 3674676,
#  'main': {'feels_like': 78.71,
#           'grnd_level': 986,
#           'humidity': 82,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 77.41,
#           'temp_max': 77.41,
#           'temp_min': 77.41},
#  'name': 'Mitú',
#  'sys': {'country': 'CO', 'sunrise': 1650710061, 'sunset': 1650753798},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 51, 'gust': 1.97, 'speed': 1.86}}
# mitu is found
#
# {'base': 'stations',
#  'clouds': {'all': 37},
#  'cod': 200,
#  'coord': {'lat': -14.9172, 'lon': 13.4925},
#  'dt': 1650770652,
#  'id': 3347762,
#  'main': {'feels_like': 54.25,
#           'grnd_level': 826,
#           'humidity': 59,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 56.16,
#           'temp_max': 56.16,
#           'temp_min': 56.16},
#  'name': 'Lubango',
#  'sys': {'country': 'AO', 'sunrise': 1650777265, 'sunset': 1650819218},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 169, 'gust': 2.64, 'speed': 1.63}}
# lubango is found
#
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 61.15, 'lon': 149.6333},
#  'dt': 1650770653,
#  'id': 2120047,
#  'main': {'feels_like': 16.38,
#           'grnd_level': 932,
#           'humidity': 71,
#           'pressure': 1006,
#           'sea_level': 1006,
#           'temp': 24.13,
#           'temp_max': 24.13,
#           'temp_min': 24.13},
#  'name': "Ust'-Omchug",
#  'sys': {'country': 'RU', 'sunrise': 1650737704, 'sunset': 1650793439},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 27, 'gust': 8.79, 'speed': 6.55}}
# ust-omchug is found

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#created DataFrame by using set varibles to create key:value pairs 

weather_df = pd.DataFrame({
    'city_name': city_name,
    'temperature': temperature, 
    'humidity': humidity, 
    'cloudiness': cloudiness, 
    'wind_speed': wind_speed, 
    'long': long,
    'lati': lati,
    'country' : country
    })
#print(temperature)
#print(city_name)

#export df to csv
weather_df.to_csv('weather.csv')
weather_df
# Out:
#         city_name  temperature  humidity  cloudiness  wind_speed      long  \
# 0    Mt. Pleasant        68.00        95           0        1.99  -79.8626
# 1       Kalispell        45.28        76         100        5.99 -114.3129
# 2            Uvat        31.50        69          91        7.36   68.8953
# 3      Bredasdorp        53.47        72          66        5.28   20.0403
# 4        Karratha        89.47        31           5       14.72  116.8463
# ..            ...          ...       ...         ...         ...       ...
# 588          Inta        17.47        85         100        3.42   60.1659
# 589       Udachny        21.45        67          99        4.05  112.4000
# 590          Mitú        77.41        82         100        1.86  -70.1733
# 591       Lubango        56.16        59          37        1.63   13.4925
# 592   Ust'-Omchug        24.13        71         100        6.55  149.6333
#
#         lati country
# 0    32.7941      US
# 1    48.1958      US
# 2    59.1433      RU
# 3   -34.5322      ZA
# 4   -20.7377      AU
# ..       ...     ...
# 588  66.0317      RU
# 589  66.4167      RU
# 590   1.1983      CO
# 591 -14.9172      AO
# 592  61.1500      RU
#
# [593 rows x 8 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# check for cities with humidity >100%
weather_df[weather_df['humidity'] >100]
# Out:
# Empty DataFrame
# Columns: [city_name, temperature, humidity, cloudiness, wind_speed, long, lati, country]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
# skip

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
weather_df.plot.scatter(x= 'lati',
                        y= 'temperature',
                        color= 'green',
                        #edgecolors= 'black',
                        alpha= .5)

plt.title("City Latitude vs. Temperature Plot")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
weather_df.plot.scatter(x= 'lati',
                        y= 'humidity',
                        color= 'green',
                        #edgecolors= 'black',
                        alpha= .5)

plt.title("City Latitude vs. Humidity Plot")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
weather_df.plot.scatter(x= 'lati',
                        y= 'cloudiness',
                        color= 'green',
                        #edgecolors= 'black',
                        alpha= .5)

plt.title("City Latitude vs. Cloudiness Plot")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
weather_df.plot.scatter(x= 'lati',
                        y= 'wind_speed',
                        color= 'green',
                        #edgecolors= 'black',
                        alpha= .5)

plt.title("City Latitude vs. Wind Speed Plot")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#northern is anything above equator 0 lati
northern_df= weather_df[weather_df['lati'] >0]

plt.scatter(northern_df['lati'],northern_df['temperature'])
m, b = np.polyfit(northern_df['lati'], northern_df['temperature'], 1)

plt.plot(northern_df['lati'], m*northern_df['lati'] + b, color = 'red')


plt.title("Northern City Latitude vs. Temperature Plot")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
southern_df= weather_df[weather_df['lati'] <0]

plt.scatter(southern_df['lati'],southern_df['temperature'])
m, b = np.polyfit(southern_df['lati'],southern_df['temperature'], 1)
plt.plot(southern_df['lati'], m*southern_df['lati'] + b, color = 'red')


plt.title("Southern City Latitude vs. Temperature Plot")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
northern_df= weather_df[weather_df['lati'] >0]

plt.scatter(northern_df['lati'],northern_df['humidity'])
m, b = np.polyfit(northern_df['lati'], northern_df['humidity'], 1)

plt.plot(northern_df['lati'], m*northern_df['lati'] + b, color = 'red')


plt.title("Northern City Latitude vs. Humidity Plot")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
southern_df= weather_df[weather_df['lati'] <0]

plt.scatter(southern_df['lati'],southern_df['humidity'])
m, b = np.polyfit(southern_df['lati'],southern_df['humidity'], 1)
plt.plot(southern_df['lati'], m*southern_df['lati'] + b, color = 'red')


plt.title("Southern City Latitude vs. Humidity Plot")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
northern_df= weather_df[weather_df['lati'] >0]

plt.scatter(northern_df['lati'],northern_df['cloudiness'])
m, b = np.polyfit(northern_df['lati'], northern_df['cloudiness'], 1)

plt.plot(northern_df['lati'], m*northern_df['lati'] + b, color = 'red')


plt.title("Northern City Latitude vs. Cloudiness Plot")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
southern_df= weather_df[weather_df['lati'] <0]

plt.scatter(southern_df['lati'],southern_df['cloudiness'])
m, b = np.polyfit(southern_df['lati'],southern_df['cloudiness'], 1)
plt.plot(southern_df['lati'], m*southern_df['lati'] + b, color = 'red')


plt.title("Southern City Latitude vs. Cloudiness Plot")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
northern_df= weather_df[weather_df['lati'] >0]

plt.scatter(northern_df['lati'],northern_df['wind_speed'])
m, b = np.polyfit(northern_df['lati'], northern_df['wind_speed'], 1)

plt.plot(northern_df['lati'], m*northern_df['lati'] + b, color = 'red')


plt.title("Northern City Latitude vs. Wind Speed Plot")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
southern_df= weather_df[weather_df['lati'] <0]

plt.scatter(southern_df['lati'],southern_df['wind_speed'])
m, b = np.polyfit(southern_df['lati'],southern_df['wind_speed'], 1)

plt.plot(southern_df['lati'], m*southern_df['lati'] + b, color = 'red')


plt.title("Southern City Latitude vs. Wind Speed Plot")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()

# %%
#Analysis
